# %% [markdown]
# # Module 2 - AI Concepts, Terminalogy, and Application Domains

# %% [markdown]
# ## 🤖 Artificial Intelligence (AI)
#
# ### 🌟 What is AI?
# - A branch of computer science that aims to build machines with human-like intelligence.
# - Core abilities:
#   - Planning
#   - Learning
#   - Reasoning
#   - Problem-solving
#   - Knowledge representation
#   - Perception & movement
#   - Social intelligence & creativity
#
# ---
#
# ### 🧩 Types of AI
# #### 🔹 Narrow AI (Weak AI)
# - Focused on one task only
# - Example: Chess engines, spam filters
#
# #### 🔹 General AI (Strong AI)
# - Human-level intelligence
# - Learns & adapts to any domain
# - Still not achieved
#
# #### 🔹 Super AI
# - Beyond human intelligence
# - Currently science fiction
#
# ---
#
# ### 📚 Machine Learning (ML)
# - Subset of AI
# - Learns from data without explicit programming
# - Example: Model trained on cat images → recognizes new cat pictures
#
# ---
#
# ### 🧠 Deep Learning (DL)
# - Subset of ML
# - Uses **deep neural networks** (multi-layered)
# - Good for large & complex data
# - Examples:
#   - Voice assistants (Siri, Alexa)
#   - Self-driving cars
#   - Face recognition
#
# ---
#
# ### 🔗 Neural Networks (NNs)
# - Inspired by the human brain
# - Structure:
#   - **Input Layer** → raw data
#   - **Hidden Layers** → process & detect patterns
#   - **Output Layer** → final prediction/classification
#
# ---
#
# ### 📝 Key Takeaways
# - 🤖 **AI** = The big umbrella of intelligence in machines
# - 📚 **ML** = Teaching machines with data (not rules)
# - 🧠 **DL** = Advanced ML with many neural layers
# - 🔗 **NNs** = The backbone of DL
# - 🚦 **Narrow AI is here, General AI is coming, Super AI is a mystery**

# %% [markdown]
# ## 🤖 Machine Learning
#
# ### 🌟 What is Machine Learning?
# - Subset of **AI**
# - Uses algorithms to **analyze data** and make **predictions/decisions**
# - Different from traditional programming:
#   - **Traditional**: Data + Rules → Output
#   - **ML**: Data + Output → Model (creates its own rules)
#
# ---
#
# ### ❤️ Example Use Case
# - Predicting **heart failure**
#   - Inputs: BPM, BMI, Age, Sex
#   - ML builds a **model** that predicts if the heart may fail
# - Traditional approach = fixed `if-then-else` rules
# - ML approach = model learns parameters & patterns from data
#
# ---
#
# ### 🔑 Why Machine Learning?
# - Can **continuously train and improve**
# - Finds **hidden patterns** in large datasets
# - Works with:
#   - Images (e.g., bird vs. cat classification)
#   - Network traffic (detecting anomalies)
#   - Games & robotics (learning strategies)
#
# ---
#
# ### 📚 Types of Machine Learning
#
# #### 🏷️ Supervised Learning
# - Trained on **labeled data**
# - Learns to classify or predict outputs
# - More data = more accuracy
# - Example: Bird vs. Cat image classifier
#
# #### 🌀 Unsupervised Learning
# - Works on **unlabeled data**
# - Finds patterns, clusters, anomalies
# - Example:
#   - Network traffic → baseline vs. outliers
#   - Customer segmentation in marketing
#
# #### 🎮 Reinforcement Learning
# - Learns through **trial & error**
# - Rewards for good actions, penalties for bad ones
# - Goal: Maximize long-term reward
# - Examples:
#   - Playing chess
#   - Navigating obstacle courses
#   - Self-driving agents
#
# ---
#
# ### 📝 Key Takeaways
# - **ML is a subset of AI** that builds models from data
# - **Traditional programming** = rules → output
# - **ML** = data + answers → model learns rules
# - **3 Types**:
#   - 🏷️ Supervised → labeled data
#   - 🌀 Unsupervised → find patterns in unlabeled data
#   - 🎮 Reinforcement → learn by reward system

# %% [markdown]
# ## 🤖 Deep Learning Overview
#
# After reading this cell, you will understand:
#
# - **AI → ML → DL**
#   - Artificial Intelligence (AI)
#   - Machine Learning (ML) → subset of AI
#   - Deep Learning (DL) → specialized subset of ML
#
# ---
#
# ### 🧠 What is Deep Learning?
# - Layers algorithms to create a **neural network** (artificial replication of brain structure & functionality).
# - Enables AI systems to:
#   - Continuously learn and improve.
#   - Handle **unstructured data** (photos, videos, audio).
#   - Understand **context & intent** in natural language.
#
# ---
#
# ### 🔄 How Does it Work?
# - DL does **not directly map input → output**.
# - Uses **multiple layers of processing units** (“deep” layers).
# - Process:
#   1. One layer outputs → next layer input.
#   2. Developers configure **number of layers** + **functions**.
#   3. Train model with **annotated examples**.
#   4. Adjusts **weights/variables** to detect patterns.
#
# 👉 Example:
# Give DL thousands of labeled images → it learns common patterns → classifies new images.
#
# ---
#
# ### ⚡ Why Deep Learning?
# - **Fixes limits of older ML algorithms**:
#   - ML plateaus as dataset grows.
#   - DL **improves with more data**.
#
# ---
#
# ### 🌍 Applications of Deep Learning
# - 🖼️ Image captioning
# - 🎙️ Voice recognition & transcription
# - 😊 Facial recognition
# - 🏥 Medical imaging
# - 🌐 Language translation
# - 🚗 Driverless cars
#
# ---
#
# ### 📌 Key Takeaways
# - DL = **subset of ML** using **layered neural networks**.
# - Learns **patterns from big data**.
# - Improves **accuracy & efficiency** over time.
# - Powers many real-world AI applications today.

# %% [markdown]
# ## 🧠 Neural Networks
#
# ### 🌟 Overview
# - Neural Networks = **computational models** inspired by the human brain.
# - Built from **neurons (nodes)** that pass information and learn patterns.
# - Power behind AI tasks like image recognition, face detection, and self-driving cars.
#
# ---
#
# ### 🏗️ Structure
# - **Input Layer** → takes raw data (e.g., pixel values of an image).
# - **Hidden Layers** → process data using **activation functions** to learn patterns.
# - **Output Layer** → final prediction/result.
# - More hidden layers = **Deep Learning**.
#
# ---
#
# ### 🔄 Learning Process
# 1. **Forward Propagation** → input moves through layers → prediction.
# 2. **Error Calculation (Loss)** → compare prediction vs actual answer.
# 3. **Backward Propagation** → send error back, adjust **weights & biases**.
# 4. Repeat until predictions improve.
#
# ---
#
# ### 🧩 Types of Neural Networks
# - **Perceptron** → simplest form (only input & output).
# - **Feed-Forward NN** → data flows one way (input → output).
# - **Deep Feed-Forward NN** → same, but with multiple hidden layers.
# - **Modular NN** → combines multiple networks for output.
# - **CNN (Convolutional Neural Network)** → best for images/visual data.
# - **RNN (Recurrent Neural Network)** → remembers past info (good for text, speech, sequences).
#
# ---
#
# ### 📌 Key Takeaways
# - Neural networks are the **foundation of AI systems**.
# - They learn by **forward & backward propagation**.
# - Different types serve different purposes:
#   - **CNNs** → vision tasks
#   - **RNNs** → sequence & language tasks
# - The deeper the network, the more complex patterns it can learn.

# %% [markdown]
# # 🍕 Machine Learning vs Deep Learning
#
# ## 🌐 Hierarchy
# - **AI (Artificial Intelligence)** → broad field.
# - **ML (Machine Learning)** → subset of AI.
# - **NN (Neural Networks)** → backbone of ML.
# - **DL (Deep Learning)** → specialized subset using deep neural networks.
#
# ---
#
# ### 🤖 Machine Learning (ML)
# - Uses **structured, labeled data** for predictions.
# - Relies heavily on **human intervention** to define features.
# - Example (Pizza Night 🍕):
#   - Inputs (X1: save time, X2: lose weight, X3: save money).
#   - Assign **weights** (importance of each factor).
#   - Use **activation function + threshold** → decision = order pizza or not.
# - Typically involves **supervised learning** (human-provided labels).
#
# ---
#
# ### 🧠 Deep Learning (DL)
# - Based on **neural networks with >3 layers** (input + hidden + output).
# - Can handle **unstructured/raw data** (images, text, audio).
# - Learns **features automatically** → less human intervention needed.
# - Can use **unsupervised learning** → discovers hidden patterns without labels.
# - Learns through **backpropagation** (error correction loop).
#
# ---
#
# ### 🔑 Key Differences
# - **ML** → shallow networks, human-defined features, structured data.
# - **DL** → deep networks, automatic feature extraction, works with unstructured data.
# - Both are subfields of **AI** and rely on **neural networks** as their foundation.
#
# ---
#
# ### 📌 Quick Takeaway
# - If it’s **pizza with just a few toppings** → Machine Learning.
# - If it’s a **fully loaded deep-dish with many layers** → Deep Learning. 🍕😅

# %% [markdown]
# # 🎨 Generative AI Models
#
# ## 🧩 What Are They?
# - Class of **AI systems** that learn from large datasets.
# - Recognize **patterns & trends**, then create **new content** (text, art, music, video).
# - Built on **machine learning & deep learning algorithms**.
#
# ---
#
# ## 🔑 Types of Generative Models
#
# ### 1️⃣ Variational Autoencoders (VAEs)
# - Structure: **Encoder → Latent Space → Decoder**.
# - Encoder compresses data into **latent features**.
# - Decoder reconstructs or generates new outputs.
# - **Uses**: image generation, anomaly detection, Fashion MNIST clothing images.
#
# ### 2️⃣ Generative Adversarial Networks (GANs)
# - Two networks: **Generator vs Discriminator**.
# - Generator makes fake data → Discriminator tests real vs fake.
# - Both improve until generated data looks real.
# - **Uses**: image synthesis, style transfer, data augmentation.
# - Famous: **Nvidia StyleGAN** (realistic faces, animals, landscapes).
#
# ### 3️⃣ Autoregressive Models
# - Generate data **sequentially** (next step depends on previous).
# - Great for **text** and **music**.
# - Example: **WaveNet** → generates natural-sounding speech/audio.
#
# ### 4️⃣ Transformers
# - Built with **encoders + decoders**.
# - Excel at **NLP tasks** (translation, chat, story generation).
# - Examples:
#   - **GPT family** (OpenAI) → text generation.
#   - **Google Gemini** → creative text tasks.
# - **Uses**: multilingual chatbots, story writing, cross-language translations.
#
# ---
#
# ## 🔀 Modalities
# - **Unimodal** → input & output in the same form (e.g., text → text).
#   - Example: **GPT-3** (text completion, Q&A, storytelling).
# - **Multimodal** → input in one form, output in another.
#   - Example: **DALL·E** (text → image).
#   - Example: **Meta’s ImageBind** (text, audio, visual, movement combined).
#
# ---
#
# ## 🚀 Why It Matters
# - Expands the **creative capacity of machines**.
# - Powers **art, design, media, and industry applications**.
# - Pushes boundaries of **human–AI collaboration**.

# %% [markdown]
# ## How Smart assistant works
# 1. Activate on hearing a specific word like "Hey, Siri".
# 2. Convert the spoken words to the text using speech-to-text(STT)
# 3. Intepret commands using natural language processing (NLP)
# 4. Execute tasks by searching databases or devices
# 5. Reponse by converting text to spoken words using text-to-speech (TTS)
#
# ## How smart thermostats work
# 1. Connect to Wi-Fi for remote control via a smartphone or computer
# 2. Learn and adjust heating and cooling preferences
# 3. Allow temperatur control with a smartphone app
# 4. Optimize heating and cooling based on schedules
# 5. Use smart sensors to detect motino and adjust the temperature
#
# ## How recommendation systems work
# 1. Collect data on viewing or listening habits to understand preferences
# 2. Create profiles to presonalize interaction
# 3. Use ML algorithms to analyze data, identify patterns, and predict content
# 4. Display recommended content to match your tastes
# 5. Updates recommendations based on ongoing interactions
#
# ## How facial recognition systems work
# 1. The camera captures a picture or video of the face
# 2. Computer vision technology detects faces
# 3. Deep learning, specifically convolutional neural networks (CNNs), extracts key facial features
# 4. ML algorithms compare these features against a database
# 5. If a match is found, the system verifies the person
#
# ## How ChatGPT works
# 1. You type a prompt into it
# 2. It uses NLP to analyze your text
# 3. The GPT model, trained on extensive data and using transformer architecture, generates a relavant response
# 4. It displays a human-like text response
#
# ## How fraud detection system works
# 1. The system gathers data (money transactions,, location, user behavior, etc)
# 2. ML learning analyzes and learns transaction patterns
# 3. The system monitors transactions in real-time, comparing each new one against established patterns
# 4. The system flags unusual transactions as potential fraud
# 5. High-risk transactions lead to automated actions such as freezing the account temporarily

# %% [markdown]
# ## 🏗️ Foundation Models
# - **Large-scale neural networks** trained on **vast & diverse datasets**.
# - Act as a **base (foundation)** for many tasks.
# - Instead of training from scratch → fine-tune a pre-trained model.
# - Examples: translation, content generation, image recognition.
# - Represent a **shift toward generalized, reusable AI**.
#
# ---
#
# ## 📚 Large Language Models (LLMs)
# - A **type of foundation model**, focused on **human language**.
# - **Large**: billions of parameters → nuanced understanding.
# - **Language**: trained on massive text → knows grammar, context, idioms.
# - **Model**: does the computation.
# - Can: answer questions, translate, write creatively.
# - Examples: **GPT family, Gemini**.
#
# ---
#
# ## 🎨 Generative AI
# - **Models designed to create new content** (text, art, music, video).
# - Uses foundation models’ knowledge → expresses creativity.
# - Think of it as **AI’s “creative side”**.
#
# ---
#
# ## 🖼️ Other Foundation Models
# - 👁️ **Vision Models** → interpret & generate images.
# - 🔬 **Scientific Models** → protein folding, biology, research.
# - 🎵 **Audio Models** → generate speech or music.
#
# ---
#
# # 🧾 Big Picture
# - **AI** → the whole field.
# - **ML** → subset of AI (learning from data).
# - **DL** → subset of ML (neural networks).
# - **Foundation Models** → large DL models, reusable for many tasks.
# - **LLMs** → foundation models for language.
# - **Generative AI** → models that create new content.

# %% [markdown]
# # 🧩 NLP, Speech Tech & Computer Vision — Summary
#
# ## 🗣️ Natural Language Processing (NLP)
# - **Definition**: Subset of AI → enables computers to understand, interpret & generate human language.
# - **Market Growth**: $29.71B → projected $158.04B in 8 years (CAGR 23.2%).
# - **How it works**:
#   - Uses ML & DL to analyze grammar, relationships, structure & context.
#   - Can detect meaning ("cloud" = weather vs. computing).
#   - Recognizes **intent & emotion** (frustration, confusion, etc.).
# - **Applications**: chatbots, translation, customer support, accessibility tools.
#
# ---
#
# ## 🎤 Speech Technology
# ### 🔊 Speech-to-Text (STT)
# - Converts **spoken words → text** using neural networks.
# - Learns from paired voice samples + transcripts.
# - **Uses**:
#   - Real-time transcription
#   - Dictation & captioning (e.g., YouTube)
#   - Virtual assistants (Siri, Google Assistant)
#   - Voice search
#
# ### 🗨️ Text-to-Speech (TTS)
# - Converts **text → spoken audio**.
# - Neural networks train on voice samples → generate natural voices.
# - **Uses**:
#   - Accessibility (screen readers)
#   - Smart devices giving voice feedback
#   - Integrated with STT + NLP for full conversation (e.g., translation tools, customer service).
#
# ---
#
# ## 👁️ Computer Vision (CV)
# - **Definition**: AI field that enables machines to interpret & understand visual data (images & video).
# - **Core Tasks**:
#   - 🏷️ **Image Classification** → categorize images (medical scans, product sorting).
#   - 🎯 **Object Detection** → recognize + locate objects (YOLO, Faster R-CNN).
#   - 🪄 **Image Segmentation** → pixel-level labeling of objects (detailed scene analysis).
# - **Applications**:
#   - 🚗 **Autonomous Vehicles** → understand surroundings.
#   - 🏬 **Retail** (Amazon, Walmart, Alibaba) → inventory mgmt, shopping personalization.
#   - 🏭 **Manufacturing** (Toyota, Siemens, Bosch) → quality control & automation.
#   - 🌱 **Agriculture** (John Deere, Monsanto) → monitor crop health, optimize farming.
#
# ---
#
# # 🧾 Big Picture
# - **NLP** → makes machines understand & use human language.
# - **Speech Tech (STT + TTS)** → bridges spoken language & computers → natural interaction.
# - **Computer Vision** → lets machines "see" & interpret the physical world.
#
# 👉 Together, these three form the **backbone of human–AI interaction**.

# %% [markdown]
# # 🗣️ Natural Language Processing (NLP) — Summary
#
# ## 🌍 What is NLP?
# - **Definition**: NLP is the field of AI that enables computers to understand, interpret, and generate human language.
# - **Analogy**: Just like you’re doing now — listening to words, forming comprehension.
# - **Key Role**: Acts as the bridge between **unstructured text** (human language) and **structured data** (machine-readable form).
#
# ---
#
# ## 🔄 Two Directions of NLP
# - **NLU (Natural Language Understanding)** → Unstructured ➝ Structured
# - **NLG (Natural Language Generation)** → Structured ➝ Unstructured
#
# ---
#
# ## 💡 Common Use Cases
# 1. **🌐 Machine Translation**
#    - Translates text across languages while preserving **context**.
#    - Bad example: *“The spirit is willing, but the flesh is weak”* → Russian → English → *“The vodka is good, but the meat is rotten.”*
#    - Shows why context matters.
#
# 2. **📱 Virtual Assistants & Chatbots**
#    - Voice-based: Siri, Alexa (derive commands).
#    - Text-based: Chatbots (traverse decision trees).
#
# 3. **😊 Sentiment Analysis**
#    - Detects tone/emotion in reviews, emails, social posts.
#    - E.g., Is text **positive**, **negative**, or **sarcastic**?
#
# 4. **📧 Spam Detection**
#    - Identifies junk mail by patterns (bad grammar, urgency, repeated words).
#
# ---
#
# ## 🛠️ Bag of Tools (How NLP Works)
# Input: **Unstructured text** (spoken or written).
# Steps:
#
# 1. **🔤 Tokenization** → Break text into words/tokens.
#    - *“Add eggs and milk to my shopping list”* → 8 tokens.
#
# 2. **🌱 Stemming** → Reduce words to their root form.
#    - *running, ran, runs → run*.
#    - ❌ Problem: *university ≠ universe*.
#
# 3. **📖 Lemmatization** → Dictionary-based root word.
#    - *better → good* (lemm), not *bet* (stem).
#
# 4. **📝 Part-of-Speech Tagging** → Identify grammatical role.
#    - *“make dinner” → verb*
#    - *“what make is your laptop” → noun*
#
# 5. **🏷️ Named Entity Recognition (NER)** → Identify real-wor

# %% [markdown]
# # AI & ML Quiz – Answers
#
# ### Question 1
# A software engineer is developing an image recognition application and is exploring various machine learning approaches. Which of the following statements accurately defines deep learning?
# **Answer:** A specialized subset of machine learning that uses artificial neural networks
#
# ---
#
# ### Question 2
# A team of AI developers is building a recommendation engine that analyzes large volumes of structured user data and requires the model to learn complex, layered relationships. Which type of neural network is best suited for this purpose?
# **Answer:** Deep feed-forward neural network
#
# ---
#
# ### Question 3
# What is the primary function of a discriminator network in a generative adversarial network (GAN)?
# **Answer:** Evaluate whether the generated data is authentic or fabricated
#
# ---
#
# ### Question 4
# Which of the following statements most accurately reflects how IoT devices generally function?
# **Answer:** IoT devices gather data and transmit it to cloud servers, where it is stored and analyzed
#
# ---
#
# ### Question 5
# Which machine learning approach involves providing an algorithm with a set of rules and constraints and letting it learn how to achieve its goals?
# **Answer:** Reinforcement learning
#
# ---
#
# ### Question 6
# A company is developing a system to categorize customer reviews into sentiments such as positive, neutral, or negative using input text features. Which machine learning technique should they use to assign labels to the reviews?
# **Answer:** Classification
#
# ---
#
# ### Question 7
# A virtual assistant reads aloud the weather forecast after you type your request. Which technology uses neural networks to generate human-like voice patterns from written text?
# **Answer:** Text-to-speech
#
# ---
#
# ### Question 8
# A logistics company is deploying smart sensors in its warehouses to track temperature and humidity levels in real time. The company wants to minimize delays in data processing and avoid network congestion. Which computing method would best suit their needs?
# **Answer:** Using a system that processes data directly at the source (Edge computing)
#
# ---
#
# ### Question 9
# Alex is working on a project that involves analyzing a massive dataset of images. His team used to spend a lot of time selecting key characteristics before training their model. However, a new approach has significantly reduced this effort by allowing the model to automatically identify relevant patterns from the data. What advancement has enabled this improvement?
# **Answer:** A method that allows models to learn patterns from raw data without manual feature selection (Deep learning)
#
# ---
#
# ### Question 10
# A neural network struggles to learn complex patterns because its layers behave like simple linear functions. What should be adjusted to allow the network to capture more intricate relationships?
# **Answer:** The function that introduces non-linearity to the model’s output (Activation function)
