# %% [markdown]
# # M3 - Business and Career transformation through AI

# %% [markdown]
# ## AI Agent
# - Engage with surrounding
# - Process Data
# - Execute Tasks independently
# - Meet Human-set goals
# ### Characteristics or key trait of AI Agent
# - **Social ability** : Communicate and Collaborate with others
# - **Autonomy** : Make decision by working alone
# - **Reactiveness** : Response quickly to changes
# - **Proactiveness** : Take initiative and make decision
#
# ### Multi-agent system:
# - Foster collaborative decision making
# - Enable distributing problem-solving
# #### Application of Multi-agent
# - Online maketplace
# - Robotic coordination
# - Traffic Management

# %% [markdown]
# # 🤖 AI Agents — The Next Step Beyond Models
#
# ## 🌊 Shift in Generative AI
# - Old style: **Monolithic models**
#   - One big model does everything, but it’s limited:
#     - Only knows what it was trained on.
#     - Hard to adapt → needs lots of retraining.
# - New style: **Compound AI Systems**
#   - Think Lego blocks 🧱: multiple components (models + tools + logic) working together.
#   - Example: Vacation days query
#     - Model alone: ❌ Wrong (it doesn’t know *your* vacation days).
#     - Compound system: ✅ Works (model queries your database, fetches real answer, returns result).
#
# ---
#
# ## ⚙️ Compound AI Systems
# - **Definition**: Systems built from multiple models + programmatic components.
# - **Modular**: You can mix and match:
#   - LLMs
#   - Image models
#   - Search engines
#   - Output verifiers
#   - Database connectors
# - **Example**: Retrieval-Augmented Generation (RAG) = LLM + search tool.
#
# - Problem: System only follows the path you predefine → if query doesn’t match the path, it fails.
#   - Example: Vacation system can’t answer “what’s the weather?” because it only looks at your HR vacation database.
#
# ---
#
# ## 🧠 Enter AI Agents
# - Instead of humans defining all control logic → let the **LLM itself control the logic**.
# - Why possible now? LLMs are getting **better at reasoning**.
#
# - Two modes of system behavior:
#   1. **Think Fast (Programmatic)** → Fixed logic, efficient, no flexibility.
#   2. **Think Slow (Agentic)** → Plan step by step, adjust when needed, use tools.
#
# ---
#
# ## 🛠️ Core Capabilities of AI Agents
# 1. **Reasoning** 🧩
#    - LLM makes a plan, breaks down the problem, adapts if needed.
#
# 2. **Acting** ⚡
#    - Use external **tools**:
#      - Search engines 🌐
#      - Database queries 📊
#      - Calculators ➕
#      - APIs or even other models.
#
# 3. **Memory** 🗂️
#    - Can remember past conversations and self-logs ("thinking out loud").
#    - Allows personalization and continuity.
#
# ---
#
# ## 🔄 Example: Sunscreen Vacation Problem
# **Question**: “How many 2oz sunscreen bottles do I need for my Florida trip?”
# Steps an AI agent might take:
# 1. Retrieve how many vacation days you have left (from memory or HR DB).
# 2. Look up Florida’s average sun hours for next month.
# 3. Check public health guidelines for sunscreen dosage.
# 4. Do math to calculate # of bottles.
# → Complex, multi-step, requires reasoning + tools + memory.
#
# ---
#
# ## 🧩 REACT Framework
# - Popular approach: **REACT = Reason + Act**.
# - Model is told:
#   1. Don’t blurt the first answer.
#   2. Think, plan, then act.
#   3. Use tools if needed.
#   4. Observe results, adjust if wrong.
# - Process repeats until final answer is ready.
#
# ---
#
# ## ⚖️ When to Use Programmatic vs Agentic
# - **Programmatic approach (fixed logic)** → best for **narrow, well-defined tasks**.
#   - Example: “Always fetch vacation days from HR database.”
#   - Faster + more efficient.
#
# - **Agentic approach (AI-led reasoning)** → best for **complex, varied tasks**.
#   - Example: “Solve GitHub issues across many domains.”
#   - More flexible, adaptable.
#
# ---
#
# ## 🚀 Big Picture
# - Compound AI systems = foundation.
# - AI Agents = compound systems **with autonomy**.
# - 2024 trend: more systems will lean **agentic** (LLMs planning, reasoning, deciding when to use tools).
# - Still early days → accuracy improving, human-in-the-loop still crucial.
#
# ---
#
# ## ⚡ Quick Analogy
# - **Programmatic system** = GPS with a fixed route.
# - **AI Agent** = GPS that reasons: reroutes when there’s traffic, checks weather, even suggests coffee stops ☕.

# %% [markdown]
# ## 🤖 AI Transforming Businesses
#
# ### 🌍 Overview
# AI is revolutionizing business operations with:
# - Smart workflow automation
# - Powerful data analysis
# - Efficient decision-making
#
# 📈 Accenture predicts:
# AI could **double workforce efficiency** and **boost profitability by 38%** in the next 10 years.
#
# ---
#
# ### 🛠 How AI Helps Businesses
#
# #### 1. 🔁 Automating Repetitive Tasks
# - Data entry
# - Scheduling
# - Report generation
# 👉 Frees employees to focus on **creative & strategic work**
#
# ---
#
# #### 2. 💬 Customer Service
# - AI chatbots handle natural language & sentiment
# - Provide **personalized support** faster & cheaper than humans
# - Example: **AirHelp** uses AI to assist airline passengers
#
# ---
#
# #### 3. 🧑‍💼 Recruitment
# - Analyzes resumes & video interviews
# - Fills positions faster, ensures quality hires
# - Example: **Hilton’s AI chatbot** answers candidate questions & schedules interviews
#
# ---
#
# #### 4. 💰 Accounting & Auditing
# - Automates payroll & auditing
# - Reduces errors, improves accuracy
# - Example: **EY** uses AI to detect fraud risks & hidden patterns
#
# ---
#
# #### 5. 📊 Data-Driven Decision Making
# - Analyzes massive datasets quickly
# - Predicts outcomes based on trends
# - Provides **real-time dashboards** for performance monitoring
#
# ---
#
# #### 6. 🛍 Marketing & Sales
# - Suggests items based on purchase history
# - Boosts sales & customer satisfaction
# - Example: **Amazon** uses AI for recommendations & inventory management
#
# ---
#
# #### 7. 🏭 Manufacturing
# - Predictive maintenance using sensors & analysis
# - Prevents costly breakdowns
# - Example: **BMW** uses AI to inspect parts & ensure quality
#
# ---
#
# #### 8. 🏥 Healthcare & Research
# - Accelerates drug discovery & disease diagnosis
# - Analyzes medical data for insights
# - Example: **IBM Healthcare** uses AI for genomic analysis
#
# ---
#
# #### 9. 🎨 Creativity & Design
# - Generates new ideas & overcomes creative blocks
# - Helps tailor designs to users
# - Example: **Canva Magic Design** suggests layouts, fonts & colors
#
# ---
#
# ### ✅ Conclusion
# AI helps businesses:
# - ⚡ Increase efficiency
# - 💸 Cut costs
# - 💡 Spark creativity
# - 🤝 Improve customer satisfaction
#
# 👉 From **chatbots to predictive analytics**, AI is not just a tool — it’s a **game-changer** for modern business.

# %% [markdown]
# ## Retrieval-Augmented Generation - RAG
#
# - **Cutting-edge** : In technology term, it refers to most `advanced`, `modern`, `innovative tools`, or `techniques` avaible in a specific fields, representing forefront(most important position or place in a specific field) of scientific and technological progress.
#
# - **RAG** is a `cutting-edge` approach in the field of natural language processing (NLP) that combines the strengths of *retrieval-based* and *generation-based* models. This hybrid method is particularly effective for tasks that require generating informative and contextually relevant text, such as question answering, dialogue systems, and content creation.
#
# ### Process of RAG
# There are three main phase of process of RAG :
# - Given a query, the model retrieves relevant documents or pieces of information from a predefined corpus or database
# - These retrieved documents are used to augment the input to the generative model, providing it with additional context.
# - The generative model uses both the original query and the retrieved information to generate a response, ensuring that the output is both contextually rich and factually grounded. This process enhances the accuracy and relevance of the generated content, addressing many limitations of standalone generative models.
#
# # ⚠️ Limitations of Generative AI Models (e.g., GPT-3, GPT-4)
#
# ## 1. 🧠 Hallucination (Making Stuff Up)
# - Models can generate **confident-sounding answers** that are **factually wrong**.
# - Example: They might give you a fake book reference or made-up statistics.
# 👉 Like a smooth talker who sometimes *BS-es* their way through.
#
# ---
#
# ## 2. 📅 Knowledge Cutoff
# - AI only knows things **up to its last training date**.
# - Example: GPT-3’s cutoff is 2021, GPT-4’s cutoff is 2023.
# 👉 If you ask about yesterday’s news, it won’t know (unless connected to the web).
#
# ---
#
# ## 3. 📝 Limited Context Window
# - Models can only "remember" a certain number of words (tokens) at once.
# - Example: Feed it a very long document → it may **forget the beginning** while reading the end.
# 👉 Like someone with short-term memory issues.
#
# ---
#
# ## 4. 🎯 Shallow Understanding
# - Text is fluent and well-structured, but often **lacks depth**.
# - Example: It can explain quantum physics in plain words but **struggles with complex math proofs**.
# 👉 A **jack-of-all-trades**: knows many things, but not in great depth.
#
# ---
#
# ## 5. 💻 Expensive & Slow
# - High-quality generation requires **a lot of computing power**.
# - More complex or long answers = slower and more costly.
# 👉 Like driving a Ferrari just to buy milk: cool, but pricey.
#
# ---
#
# # 🔑 Summary
# Generative AI is **powerful** but not perfect.
#
# ✔️ Great at:
# - Explaining concepts
# - Brainstorming ideas
# - Writing smoothly
#
# ❌ Weak at:
# - Avoiding hallucinations
# - Giving real-time info
# - Remembering long conversations
# - Handling deep technical details
# - Running cheaply at scale
#
# 👉 **Think of AI as a clever assistant, not an all-knowing professor.**
# Use it for **speed + creativity**, but always **fact-check the output**.

# %% [markdown]
# # 🔍 Retrieval-Augmented Generation (RAG)
#
# RAG is a hybrid approach that **combines retrieval (searching for real data)** with **generation (AI writing)**.
# It addresses many of the key limitations of generative AI models like GPT-3 or GPT-4.
#
# ---
#
# ## ⚠️ How RAG Fixes Generative AI Limitations
#
# ### 1. 🧠 Reducing Hallucination
# - Instead of making things up, RAG **grounds answers in retrieved documents**.
# - Ensures factual and contextually accurate responses.
#
# ### 2. 📅 Knowledge Cutoff
# - RAG can **fetch real-time data** from up-to-date databases.
# - Solves the "frozen in time" issue of standard LLMs.
#
# ### 3. 📝 Limited Context Window
# - Retrieval provides **relevant chunks of text** on-demand.
# - Extends effective memory, so the model stays coherent over longer conversations.
#
# ### 4. 🎯 Shallow Understanding
# - By pulling **specific documents**, RAG adds **depth and precision**.
# - Answers become more detailed and query-specific.
#
# ### 5. 💻 Efficiency
# - Retrieval narrows the information space, so the generator focuses on **synthesizing relevant info** instead of guessing.
# - Often more efficient and faster.
#
# ---
#
# ## ⚙️ RAG: Key Components
#
# ### 🔎 Retrieval Component
# - **Function:** Searches and extracts relevant info from a large corpus or database.
# - **Mechanism:** Uses retrievers like:
#   - BM25 (classic search)
#   - Dense neural retrievers (e.g., DPR, ColBERT)
#
# ### ✍️ Generation Component
# - **Function:** Generates coherent, contextual text using retrieved info.
# - **Mechanism:** A generative model (e.g., GPT, BERT variants) processes retrieved chunks + query.
# - Produces **fact-grounded, fluent output**.
#
# ---
#
# ## ✅ Benefits of RAG
#
# - **Accuracy** → Grounded in actual data.
# - **Relevance** → Retrieval ensures context-specific answers.
# - **Freshness** → Can access up-to-date information.
# - **Flexibility** → Works for multiple NLP tasks.
# - **Scalability** → Efficient handling of large corpora.
#
# ---
#
# ## 💡 Applications of RAG
#
# - **Question Answering** → Retrieves docs for accurate, complex answers.
# - **Content Creation** → Assists in writing articles, reports, creative pieces.
# - **Customer Support** → Provides precise, real-time policy or product info.
# - **Search Engines** → Returns detailed answers instead of just links.
#
# ---
#
# ## ☁️ RAG on Google Cloud
#
# ### 🔧 Key Tools
# - **Vertex AI** → Build & deploy ML models, including RAG frameworks.
# - **BigQuery** → Efficient large-scale querying for retrieval.
#
# ### ⭐ Features
# - **Scalability** → Handles massive data efficiently.
# - **Integration** → Works with multiple APIs and data sources.
# - **Customization** → Tailor RAG to industry-specific needs.
#
# ---
#
# ## 📚 Example
#
# **Query:** *"What were the key causes of World War II?"*
# 1. **Retrieval:** Fetches passages from a history database about WWII causes.
# 2. **Generation:** Synthesizes a well-structured, accurate explanation.
#
# Result → A **fact-based, informative answer** instead of a guess.
#
# ---
#
# ## 🏆 Example Use Case: Customer Support
# - **Without RAG:** LLM might hallucinate outdated policies.
# - **With RAG + BigQuery:** Retrieves the latest company policies and generates accurate, up-to-date responses.
#
# 👉 This ensures **customer trust**, reduces errors, and strengthens brand reputation.

# %% [markdown]
# # AI Adoption
# It means using AI in business to help with tasks, make things easire, or bring new ideas
# ## Benefits of adopting AI in business:
# - Increase efficiency
# - Enhance decision-making
# - Improve customer-service
# - Drive Innovation
#
# ## General steps to adopt AI in business
# - `Define businees goal`: Identify the problems and set clear goals
# - `Identify suitable use cases`: Identify areas to apply AI
# - `Data readines`: Collect data followed by cleaning and organizing
# - `Build AI capabilities`: Train employees and develop the necessary setup
# - `Deploy AI`: Integrate with existing systems
# - `Monitor and optimize AI systems`: Ensure smooth functioning
#
# ## AI Adoption Frameworks : Amazon, OpenAI,and Facebook
# The main components of the frameworks for adopting AI are:
# - **Data preparation**:
#   - Collecting, cleaning, and organizing data. Ensuring data quality and relevance for model training.
# - **Model development**:
#   - Designing and training  AI models.
#   - Using algorithms and frameworks to create predictive models.
# - **Deployment**:
#   - Integrating models into production environments.
#   - Ensuring models are scalable and reliable.
# - **Optimization:**
#   - Continuously monitoring and improving model performance.
#   - Updating models based on new data and feedback.
#
# ## AI-Related job opportunities
# ### NOT PROGRAMMING LANGUAGE REQUIRED
# - AI Engineer
# - Data Scientist
# - Robotics Engineer
# - NLP Engineer
# - AI Application developer
# - AI research scientist
# ### REQUIRED PROGRAMMING LANGUAGE
# - AI ethicist
# - AI product manager
# - AI strategist
# - AI marketing specialist

# %% [markdown]
# # Module Summary
# ---
#
# ## 🤖 AI Agents
# - Agents in AI are software programs that **engage with surroundings, process data, and autonomously carry out tasks** to meet human-defined goals.
#
# ---
#
# ## 🦾 Robotics & Cobots
# - **Robotics** involves designing, constructing, and operating robots to perform tasks with or without humans.
# - **Cobots** collaborate with humans using advanced sensors and AI, communicating and coordinating tasks that require teamwork.
#
# ---
#
# ## ⚙️ Robotic Process Automation (RPA)
# - Automates repetitive tasks.
# - Helps create, use, and control **virtual robots**.
#
# ---
#
# ## 🏢 AI in Business
# - Automates repetitive tasks like **data entry, scheduling, and report generation**.
# - Enables employees to focus on **creative and strategic work**.
# - Swiftly analyzes large data volumes → identifies patterns & trends.
# - Leads to fewer errors and better predictions.
# - Generates innovative ideas and overcomes creative blocks.
#
# ---
#
# ## 🧠 Evolution of AI
# - Early AI: **Rule-based systems**, lacked creativity.
# - Deep learning: Enabled AI to **learn and adapt like the human brain**.
# - **Generative Adversarial Networks (GANs):** Breakthrough in creating high-quality images, music, design, and medicine.
#
# ---
#
# ## 🌟 Generative AI Contributions
# - **Content generation:** Creates unique content by analyzing data.
# - **Data analysis:** Finds patterns and generates actionable reports.
# - **Customer service:** Provides fast, personalized responses.
# - **Product development:** Produces multiple design variations quickly.
#
# ---
#
# ## 🚀 Adopting AI in Business
# 1. **Define business goals** – Identify problems and set clear goals.
# 2. **Identify suitable use cases** – Areas to apply AI.
# 3. **Data readiness** – Collect, clean, and organize data.
# 4. **Build AI capabilities** – Train employees, develop setup.
# 5. **Deploy AI solutions** – Integrate with existing systems.
# 6. **Monitor & optimize** – Ensure smooth functioning.
#
# ---
#
# ## 💼 AI in Organizations
# - Automates **employee engagement, recruitment, onboarding, performance management**.
# - **Chatbots** transform customer interactions.
# - Enhances **efficiency, decision-making, customer service, and innovation**.
#
# ---
#
# ## 🛠️ AI Tools & Platforms
# - **ChatGPT, Gemini** → versatile applications.
# - **Copy.ai, Jasper, Synthesia** → marketing & content creation.
# - **Grammarly, QuillBot** → writing & communication.
# - **Duolingo, Google Translate, Babel** → language learning & translation.
# - **AI chatbots, Zendesk, LivePerson** → customer service.
# - **Tableau, Power BI** → data analysis & visualization.
# - **GitHub Copilot** → assists developers in coding.
# - **Todoist, Microsoft To Do, Evernote** → task management.
#
# ---
#
# ## 🎯 Career in AI
# To switch to an AI-related career:
# - Identify **existing skills** that can be leveraged.
# - Learn **core AI concepts**.
# - Apply skills **practically**.
# - Stay updated with **latest trends**.
# - Delve deeper into **specialized areas of AI**.
#
# **Job Profiles:**
# - **AI Ethicist:** Ensure AI is ethical, considering social & moral implications.
# - **AI Product Manager:** Oversee AI product development & implementation.
# - **AI Strategist:** Develop long-term AI strategies for business.
# - **AI Marketing Specialist:** Use AI to analyze consumer data & optimize strategies.
#
# ---

# %% [markdown]
# # Quizes
# 1. A home appliance company is designing a smart vacuum cleaner that can move around without bumping into furniture or falling off stairs. Which component helps the robot detect its environment, including obstacles and drop-offs?
# **Answer:** Sensors
#
# 2. Which AI capability helps companies reduce stockouts and excess inventory by predicting which items will be needed in the future?
# **Answer:** Predicting future demand based on sales and market trends
#
# 3. How is generative AI enhancing marketing efforts in businesses?
# **Answer:** By generating personalized emails and product descriptions
#
# 4. A major bank uses AI to detect fraudulent transactions, assess credit risk, and offer personalized financial advice. Which industry does this example represent?
# **Answer:** Financial services
#
# 5. A company is launching a new line of products but is stuck in the early design phase due to limited concepts and slow iteration. How can generative AI support the team at this stage?
# **Answer:** By rapidly producing a wide variety of early-stage design options
#
# 6. Peter, an international business consultant, often communicates with clients who speak different languages. Which AI tool does he rely on during client calls to ensure clear and accurate communication across languages?
# **Answer:** Google Translate
#
# 7. Which type of robot integrates advanced sensors and AI to safely share workspaces and coordinate actions with human workers?
# **Answer:** A collaborative robot built for real-time human–robot interaction
#
# 8. Which AI career role is most likely to suit someone who has strong communication and customer service skills and has recently developed experience in Python and NLP?
# **Answer:** AI chatbot developer for customer support platforms
#
# 9. Which AI tools are leveraged by social media teams to revise written content, improve grammar, and ensure stylistic consistency before publishing?
# **Answer:** Grammarly and QuillBot
#
# 10. Which application of generative AI best improves customer service by offering personalized and immediate assistance?
# **Answer:** Powering assistants that understand and respond to customers instantly
